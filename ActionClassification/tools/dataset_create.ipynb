# %% [markdown]
# ## Creating dataset of different activities
# This scripts read the action annotation text files provided for each long video. extracts the start and end time of each action and trim the pose estimation results for the long video based on the start and end time. the trimed results is written to the folder related to the annotated action.

# %%
# import required packages
import sys
import os
import io
import cPickle as pickle
import os.path as osp
import numpy as np
import pylab
import math
import shutil
import glob
import re
from copy import deepcopy

# %% [markdown]
# ### Definition of requires functions and variables

# %%
def _id_or_index(ix, val):
    if len(val) == 0:
        return val
    else:
        return val[ix]
def robust_pickle_dump(data_dict, file_name):
    file_name = os.path.abspath(file_name)
    with open(file_name, 'wb') as f:
        pickle.dump(data_dict, f, pickle.HIGHEST_PROTOCOL)
DTYPE = np.float32
height = 1080  # frame height in pixel
width = 1920  # frame width in pixel
fps = 30.0

# %%
pose_base_path = '../../PoseTracking/outputs/TuftsVideos'
actions = ['Sitting', 'Sit-to-Stand', 'Stand-to-Sit', 'Standing', 'Walking']
base_data_path = '../input/TuftsVideos/Posture/test'
max_len = 4  # in seconds
min_len = 0.2
for subj_id in range(32,35,1):
#    for visit_no in [1, 2]:
        visit_no = 1
        annotation_path = '../TuftsVideo_annotations/121601_{:02d}{:02d}'.format(subj_id, visit_no)
        annotation_file_name = '121601_{:02d}{:02d}_Arbitration.txt'.format(subj_id, visit_no)
        pose_data_path = glob.glob(osp.join(pose_base_path, '031216010{:02d}'.format(subj_id), 
                                            'Visit_{:02d}'.format(visit_no),'*.pkl'))
        print('---processing subject {:2d} visit {:2d}'.format(subj_id, visit_no))
# reading the pose results
        with open(pose_data_path[0], 'rb') as res:
            target_dets = pickle.load(res)    # {'target_boxes':[], 'target_keyps':[]}
# reading annotation file
        delimiters = ",","\t", "\n", "\t\t"
        regexpattern = '|'.join(map(re.escape, delimiters))
# read the posture related annotations in a list
        annot_list = []
        with open(osp.join(annotation_path, annotation_file_name), 'rb') as f:
            for line in f:
                temp = re.split(regexpattern, line)
                temp = list(filter(lambda x: x!= '', temp))
                if temp[0]=='Posture':
                    annot_list.append(temp[:7])
            #print(temp[:7])

### Making a list of all actions and save the clip results in the corresponding action folder

# creat proper folders according to the labels if there do not exist
        
        for i in range(len(annot_list)):
            st_t = float(annot_list[i][3])
            end_t = float(annot_list[i][4])
            length = float(annot_list[i][5])
            act = annot_list[i][6]
            if length < min_len:
                print('---Data between {} and {} related to action {} is removed due to the duration below {} seconds'
                      .format(st_t, end_t, act, min_len))
            if act in actions and length > min_len:
                if length <= max_len:
                    print('---Data between {} and {} related to action {} with duration {} is saved'
                      .format(st_t, end_t, act, length))
                    st_fr = int(st_t * fps)
                    end_fr = int(end_t * fps)
                    clip_name = '{:02d}{:02d}_{:06d}_{:06d}.pkl'.format(subj_id, visit_no, st_fr, end_fr)
                    dest_file = osp.join(base_data_path, act, clip_name)
                    clip = dict(target_boxes = target_dets['target_boxes'][st_fr:end_fr],
                           target_keyps = target_dets['target_keyps'][st_fr:end_fr])
                    robust_pickle_dump(clip, dest_file)
                else:
                    clip_no = int(length // max_len)
                    resid = length % max_len
                    print('---Data between {} and {} related to {} is devided to {} clips with length of {} seconds each'
                          .format(st_t, end_t, act, clip_no, max_len))
                    for i in range(clip_no):
                        st_fr = int((st_t + i*max_len) * fps)
                        end_fr = int((st_t + (i+1)*max_len) * fps)-1
                        clip_name = '{:02d}{:02d}_{:06d}_{:06d}.pkl'.format(subj_id, visit_no, st_fr, end_fr)
                        dest_file = osp.join(base_data_path, act, clip_name)
                        clip = dict(target_boxes = target_dets['target_boxes'][st_fr:end_fr],
                        target_keyps = target_dets['target_keyps'][st_fr:end_fr])
                        robust_pickle_dump(clip, dest_file)
                    if resid > min_len:
                        print('---Residual of the data between {} and {} related to action {} with duration {} is saved'
                              .format(st_t, end_t, act, resid))
                        st_fr = int((st_t + clip_no*max_len) * fps)
                        end_fr = int(end_t * fps)
                        clip_name = '{:02d}{:02d}_{:06d}_{:06d}.pkl'.format(subj_id, visit_no, st_fr, end_fr)
                        dest_file = osp.join(base_data_path, act, clip_name)
                        clip = dict(target_boxes = target_dets['target_boxes'][st_fr:end_fr],
                        target_keyps = target_dets['target_keyps'][st_fr:end_fr])
                        robust_pickle_dump(clip, dest_file)
# Out:
# ---processing subject 32 visit  1
# ---Data between 0.0 and 641.474 related to Sitting is devided to 160 clips with length of 4 seconds each
# ---Residual of the data between 0.0 and 641.474 related to action Sitting with duration 1.474 is saved
# ---Data between 641.474 and 641.641 related to action PGT N/A is removed due to the duration below 0.2 seconds
# ---Data between 641.641 and 655.221 related to Sitting is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 641.641 and 655.221 related to action Sitting with duration 1.58 is saved
# ---Data between 655.521 and 949.682 related to Sitting is devided to 73 clips with length of 4 seconds each
# ---Residual of the data between 655.521 and 949.682 related to action Sitting with duration 2.161 is saved
# ---Data between 949.682 and 951.016 related to action Sit-to-Stand with duration 1.334 is saved
# ---Data between 951.016 and 952.318 related to action Sit-to-Stand with duration 1.302 is saved
# ---Data between 952.318 and 952.618 related to action Stand-to-Sit with duration 0.3 is saved
# ---Data between 952.618 and 953.185 related to action Sitting with duration 0.567 is saved
# ---Data between 953.185 and 955.287 related to action Sit-to-Stand with duration 2.102 is saved
# ---Data between 955.287 and 955.754 related to action Stand-to-Sit with duration 0.467 is saved
# ---Data between 955.754 and 959.692 related to action Sitting with duration 3.938 is saved
# ---Data between 959.692 and 971.77 related to Sit-to-Stand is devided to 3 clips with length of 4 seconds each
# ---Data between 971.77 and 976.308 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 971.77 and 976.308 related to action Sit-to-Stand with duration 0.538 is saved
# ---Data between 976.308 and 1000.699 related to Sitting is devided to 6 clips with length of 4 seconds each
# ---Residual of the data between 976.308 and 1000.699 related to action Sitting with duration 0.391 is saved
# ---Data between 1000.699 and 1005.704 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1000.699 and 1005.704 related to action Sit-to-Stand with duration 1.005 is saved
# ---Data between 1005.704 and 1016.515 related to Sit-to-Stand is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 1005.704 and 1016.515 related to action Sit-to-Stand with duration 2.811 is saved
# ---Data between 1016.515 and 1044.877 related to Sitting is devided to 7 clips with length of 4 seconds each
# ---Residual of the data between 1016.515 and 1044.877 related to action Sitting with duration 0.362 is saved
# ---Data between 1044.877 and 1047.78 related to action Sit-to-Stand with duration 2.903 is saved
# ---Data between 1047.78 and 1049.982 related to action Sitting with duration 2.202 is saved
# ---Data between 1049.982 and 1054.586 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1049.982 and 1054.586 related to action Sit-to-Stand with duration 0.604 is saved
# ---Data between 1054.586 and 1060.059 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1054.586 and 1060.059 related to action Sit-to-Stand with duration 1.473 is saved
# ---Data between 1060.059 and 1072.371 related to Sitting is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 1060.059 and 1072.371 related to action Sitting with duration 0.312 is saved
# ---Data between 1072.371 and 1073.672 related to action Sit-to-Stand with duration 1.301 is saved
# ---Data between 1073.672 and 1074.406 related to action Sitting with duration 0.734 is saved
# ---Data between 1074.406 and 1079.945 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1074.406 and 1079.945 related to action Sit-to-Stand with duration 1.539 is saved
# ---Data between 1079.945 and 1094.86 related to Sitting is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 1079.945 and 1094.86 related to action Sitting with duration 2.915 is saved
# ---Data between 1094.86 and 1100.499 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1094.86 and 1100.499 related to action Sit-to-Stand with duration 1.639 is saved
# ---Data between 1103.001 and 1104.903 related to action Walking with duration 1.902 is saved
# ---Data between 1116.582 and 1209.241 related to Standing is devided to 23 clips with length of 4 seconds each
# ---Residual of the data between 1116.582 and 1209.241 related to action Standing with duration 0.659 is saved
# ---Data between 1228.026 and 1266.031 related to Standing is devided to 9 clips with length of 4 seconds each
# ---Residual of the data between 1228.026 and 1266.031 related to action Standing with duration 2.005 is saved
# ---Data between 1276.875 and 1280.712 related to action Walking with duration 3.837 is saved
# ---Data between 1307.606 and 1331.697 related to Standing is devided to 6 clips with length of 4 seconds each
# ---Data between 1342.774 and 1344.609 related to action Standing with duration 1.835 is saved
# ---Data between 1355.12 and 1356.121 related to action Standing with duration 1.001 is saved
# ---Data between 1356.121 and 1376.475 related to Walking is devided to 5 clips with length of 4 seconds each
# ---Residual of the data between 1356.121 and 1376.475 related to action Walking with duration 0.354 is saved
# ---Data between 1378.143 and 1383.949 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1378.143 and 1383.949 related to action Walking with duration 1.806 is saved
# ---Data between 1384.816 and 1392.057 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1384.816 and 1392.057 related to action Walking with duration 3.241 is saved
# ---Data between 1435.3 and 1436.334 related to action Standing with duration 1.034 is saved
# ---Data between 1450.949 and 1537.736 related to Walking is devided to 21 clips with length of 4 seconds each
# ---Residual of the data between 1450.949 and 1537.736 related to action Walking with duration 2.787 is saved
# ---Data between 1538.77 and 1584.816 related to Walking is devided to 11 clips with length of 4 seconds each
# ---Residual of the data between 1538.77 and 1584.816 related to action Walking with duration 2.046 is saved
# ---Data between 1603.335 and 1605.737 related to action Standing with duration 2.402 is saved
# ---Data between 1612.31 and 1613.578 related to action Standing with duration 1.268 is saved
# ---Data between 1619.651 and 1628.36 related to Walking is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 1619.651 and 1628.36 related to action Walking with duration 0.709 is saved
# ---Data between 1646.011 and 1912.788 related to Sitting is devided to 66 clips with length of 4 seconds each
# ---Residual of the data between 1646.011 and 1912.788 related to action Sitting with duration 2.777 is saved
# ---Data between 1912.788 and 1912.921 related to action PGT N/A is removed due to the duration below 0.2 seconds
# ---Data between 1912.921 and 2150.35 related to Sitting is devided to 59 clips with length of 4 seconds each
# ---Residual of the data between 1912.921 and 2150.35 related to action Sitting with duration 1.429 is saved
# ---Data between 2151.649 and 3171.234 related to Sitting is devided to 254 clips with length of 4 seconds each
# ---Residual of the data between 2151.649 and 3171.234 related to action Sitting with duration 3.585 is saved
# ---Data between 3171.234 and 3171.401 related to action PGT N/A is removed due to the duration below 0.2 seconds
# ---Data between 3171.401 and 3191.922 related to Sitting is devided to 5 clips with length of 4 seconds each
# ---Residual of the data between 3171.401 and 3191.922 related to action Sitting with duration 0.521 is saved
# ---Data between 3191.922 and 3200.33 related to Sit-to-Stand is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 3191.922 and 3200.33 related to action Sit-to-Stand with duration 0.408 is saved
# ---Data between 3214.311 and 3231.962 related to Walking is devided to 4 clips with length of 4 seconds each
# ---Residual of the data between 3214.311 and 3231.962 related to action Walking with duration 1.651 is saved
# ---Data between 3238.034 and 3239.174 related to action Standing with duration 1.14 is saved
# ---Data between 3239.174 and 3239.241 related to action PGT N/A is removed due to the duration below 0.2 seconds
# ---Data between 3239.241 and 3346.476 related to Standing is devided to 26 clips with length of 4 seconds each
# ---Residual of the data between 3239.241 and 3346.476 related to action Standing with duration 3.235 is saved
# ---Data between 3346.476 and 3346.643 related to action PGT N/A is removed due to the duration below 0.2 seconds
# ---Data between 3372.569 and 3377.407 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3372.569 and 3377.407 related to action Walking with duration 0.838 is saved
# ---Data between 3378.141 and 3380.076 related to action Walking with duration 1.935 is saved
# ---Data between 3380.076 and 3382.312 related to action Stand-to-Sit with duration 2.236 is saved
# ---Data between 3382.312 and 3774.67 related to Sitting is devided to 98 clips with length of 4 seconds each
# ---Residual of the data between 3382.312 and 3774.67 related to action Sitting with duration 0.358 is saved
# ---Data between 3774.67 and 3781.577 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3774.67 and 3781.577 related to action Sit-to-Stand with duration 2.907 is saved
# ---Data between 3794.59 and 3800.496 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3794.59 and 3800.496 related to action Walking with duration 1.906 is saved
# ---Data between 3841.571 and 3841.704 related to action PGT N/A is removed due to the duration below 0.2 seconds
# ---Data between 3855.085 and 3865.094 related to Walking is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 3855.085 and 3865.094 related to action Walking with duration 2.009 is saved
# ---Data between 4199.261 and 4212.208 related to Walking is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 4199.261 and 4212.208 related to action Walking with duration 0.947 is saved
# ---Data between 4212.208 and 4214.476 related to action Standing with duration 2.268 is saved
# ---Data between 4239.501 and 4241.503 related to action Standing with duration 2.002 is saved
# ---Data between 4273.869 and 4277.139 related to action Walking with duration 3.27 is saved
# ---Data between 4277.139 and 4278.707 related to action Standing with duration 1.568 is saved
# ---Data between 4278.707 and 4319.014 related to Walking is devided to 10 clips with length of 4 seconds each
# ---Residual of the data between 4278.707 and 4319.014 related to action Walking with duration 0.307 is saved
# ---Data between 4319.014 and 4321.684 related to action Standing with duration 2.67 is saved
# ---Data between 4325.387 and 4328.691 related to action Walking with duration 3.304 is saved
# ---Data between 4379.241 and 4385.247 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 4379.241 and 4385.247 related to action Walking with duration 2.006 is saved
# ---Data between 4385.247 and 4388.317 related to action Standing with duration 3.07 is saved
# ---Data between 4388.317 and 4437.166 related to Walking is devided to 12 clips with length of 4 seconds each
# ---Residual of the data between 4388.317 and 4437.166 related to action Walking with duration 0.849 is saved
# ---Data between 4437.166 and 4533.128 related to Standing is devided to 23 clips with length of 4 seconds each
# ---Residual of the data between 4437.166 and 4533.128 related to action Standing with duration 3.962 is saved
# ---Data between 4551.513 and 4562.09 related to Walking is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 4551.513 and 4562.09 related to action Walking with duration 2.577 is saved
# ---processing subject 33 visit  1
# ---Data between 0.0 and 512.578 related to Sitting is devided to 128 clips with length of 4 seconds each
# ---Residual of the data between 0.0 and 512.578 related to action Sitting with duration 0.578 is saved
# ---Data between 512.945 and 525.291 related to Sitting is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 512.945 and 525.291 related to action Sitting with duration 0.346 is saved
# ---Data between 525.658 and 538.941 related to Sitting is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 525.658 and 538.941 related to action Sitting with duration 1.283 is saved
# ---Data between 538.941 and 539.008 related to action PGT N/A is removed due to the duration below 0.2 seconds
# ---Data between 539.009 and 549.249 related to Sitting is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 539.009 and 549.249 related to action Sitting with duration 2.24 is saved
# ---Data between 549.249 and 549.415 related to action PGT N/A is removed due to the duration below 0.2 seconds
# ---Data between 549.415 and 790.456 related to Sitting is devided to 60 clips with length of 4 seconds each
# ---Residual of the data between 549.415 and 790.456 related to action Sitting with duration 1.041 is saved
# ---Data between 790.456 and 794.493 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Data between 794.493 and 796.462 related to action Stand-to-Sit with duration 1.969 is saved
# ---Data between 796.462 and 823.355 related to Sitting is devided to 6 clips with length of 4 seconds each
# ---Residual of the data between 796.462 and 823.355 related to action Sitting with duration 2.893 is saved
# ---Data between 823.355 and 825.724 related to action Sit-to-Stand with duration 2.369 is saved
# ---Data between 825.724 and 825.958 related to action Standing with duration 0.234 is saved
# ---Data between 825.958 and 827.76 related to action Stand-to-Sit with duration 1.802 is saved
# ---Data between 827.76 and 829.962 related to action Sitting with duration 2.202 is saved
# ---Data between 829.962 and 831.13 related to action Sit-to-Stand with duration 1.168 is saved
# ---Data between 831.13 and 832.097 related to action Stand-to-Sit with duration 0.967 is saved
# ---Data between 832.097 and 840.239 related to Sitting is devided to 2 clips with length of 4 seconds each
# ---Data between 840.239 and 842.208 related to action Sit-to-Stand with duration 1.969 is saved
# ---Data between 844.276 and 845.411 related to action Stand-to-Sit with duration 1.135 is saved
# ---Data between 845.411 and 857.189 related to Sitting is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 845.411 and 857.189 related to action Sitting with duration 3.778 is saved
# ---Data between 857.189 and 857.756 related to action Sit-to-Stand with duration 0.567 is saved
# ---Data between 857.756 and 859.124 related to action Sitting with duration 1.368 is saved
# ---Data between 859.124 and 860.025 related to action Sit-to-Stand with duration 0.901 is saved
# ---Data between 860.025 and 860.726 related to action Sitting with duration 0.701 is saved
# ---Data between 860.726 and 861.462 related to action Sit-to-Stand with duration 0.736 is saved
# ---Data between 861.462 and 861.796 related to action Stand-to-Sit with duration 0.334 is saved
# ---Data between 861.796 and 862.428 related to action Sitting with duration 0.632 is saved
# ---Data between 862.428 and 863.562 related to action Sit-to-Stand with duration 1.134 is saved
# ---Data between 863.562 and 863.929 related to action Stand-to-Sit with duration 0.367 is saved
# ---Data between 863.929 and 866.298 related to action Sitting with duration 2.369 is saved
# ---Data between 866.298 and 867.333 related to action Sit-to-Stand with duration 1.035 is saved
# ---Data between 867.333 and 867.6 related to action Stand-to-Sit with duration 0.267 is saved
# ---Data between 867.6 and 868.067 related to action Sitting with duration 0.467 is saved
# ---Data between 868.067 and 868.934 related to action Sit-to-Stand with duration 0.867 is saved
# ---Data between 868.934 and 869.301 related to action Stand-to-Sit with duration 0.367 is saved
# ---Data between 869.301 and 869.935 related to action Sitting with duration 0.634 is saved
# ---Data between 869.935 and 871.203 related to action Sit-to-Stand with duration 1.268 is saved
# ---Data between 871.203 and 871.57 related to action Stand-to-Sit with duration 0.367 is saved
# ---Data between 871.57 and 875.946 related to Sitting is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 871.57 and 875.946 related to action Sitting with duration 0.376 is saved
# ---Data between 875.946 and 878.484 related to action Sit-to-Stand with duration 2.538 is saved
# ---Data between 879.053 and 883.883 related to Sitting is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 879.053 and 883.883 related to action Sitting with duration 0.83 is saved
# ---Data between 883.883 and 885.618 related to action Sit-to-Stand with duration 1.735 is saved
# ---Data between 885.618 and 886.352 related to action Standing with duration 0.734 is saved
# ---Data between 886.352 and 887.453 related to action Stand-to-Sit with duration 1.101 is saved
# ---Data between 887.453 and 919.919 related to Sitting is devided to 8 clips with length of 4 seconds each
# ---Residual of the data between 887.453 and 919.919 related to action Sitting with duration 0.466 is saved
# ---Data between 919.919 and 921.52 related to action Sit-to-Stand with duration 1.601 is saved
# ---Data between 921.52 and 922.354 related to action Stand-to-Sit with duration 0.834 is saved
# ---Data between 922.354 and 922.855 related to action Sitting with duration 0.501 is saved
# ---Data between 922.855 and 923.455 related to action Sit-to-Stand with duration 0.6 is saved
# ---Data between 923.455 and 923.789 related to action Stand-to-Sit with duration 0.334 is saved
# ---Data between 923.789 and 924.39 related to action Sitting with duration 0.601 is saved
# ---Data between 924.39 and 925.658 related to action Sit-to-Stand with duration 1.268 is saved
# ---Data between 925.658 and 926.125 related to action Stand-to-Sit with duration 0.467 is saved
# ---Data between 926.125 and 926.625 related to action Sitting with duration 0.5 is saved
# ---Data between 926.625 and 927.893 related to action Sit-to-Stand with duration 1.268 is saved
# ---Data between 927.893 and 929.995 related to action Sitting with duration 2.102 is saved
# ---Data between 929.995 and 930.696 related to action Sit-to-Stand with duration 0.701 is saved
# ---Data between 930.696 and 931.297 related to action Sitting with duration 0.601 is saved
# ---Data between 931.297 and 931.931 related to action Sit-to-Stand with duration 0.634 is saved
# ---Data between 931.931 and 932.932 related to action Sitting with duration 1.001 is saved
# ---Data between 932.932 and 933.832 related to action Sit-to-Stand with duration 0.9 is saved
# ---Data between 933.832 and 934.3 related to action Sitting with duration 0.468 is saved
# ---Data between 934.3 and 936.001 related to action Sit-to-Stand with duration 1.701 is saved
# ---Data between 936.001 and 936.669 related to action Standing with duration 0.668 is saved
# ---Data between 936.669 and 937.569 related to action Stand-to-Sit with duration 0.9 is saved
# ---Data between 937.569 and 938.237 related to action Sitting with duration 0.668 is saved
# ---Data between 938.237 and 939.104 related to action Sit-to-Stand with duration 0.867 is saved
# ---Data between 939.104 and 939.672 related to action Sitting with duration 0.568 is saved
# ---Data between 939.672 and 941.24 related to action Sit-to-Stand with duration 1.568 is saved
# ---Data between 941.24 and 941.907 related to action Standing with duration 0.667 is saved
# ---Data between 941.907 and 943.309 related to action Stand-to-Sit with duration 1.402 is saved
# ---Data between 943.309 and 952.484 related to Sitting is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 943.309 and 952.484 related to action Sitting with duration 1.175 is saved
# ---Data between 952.484 and 955.387 related to action Sit-to-Stand with duration 2.903 is saved
# ---Data between 956.088 and 958.557 related to action Walking with duration 2.469 is saved
# ---Data between 958.557 and 1095.227 related to Standing is devided to 34 clips with length of 4 seconds each
# ---Residual of the data between 958.557 and 1095.227 related to action Standing with duration 0.67 is saved
# ---Data between 1108.507 and 1110.409 related to action Standing with duration 1.902 is saved
# ---Data between 1110.409 and 1121.42 related to Walking is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 1110.409 and 1121.42 related to action Walking with duration 3.011 is saved
# ---Data between 1122.821 and 1155.921 related to Standing is devided to 8 clips with length of 4 seconds each
# ---Residual of the data between 1122.821 and 1155.921 related to action Standing with duration 1.1 is saved
# ---Data between 1158.991 and 1159.992 related to action Standing with duration 1.001 is saved
# ---Data between 1159.992 and 1203.101 related to Walking is devided to 10 clips with length of 4 seconds each
# ---Residual of the data between 1159.992 and 1203.101 related to action Walking with duration 3.109 is saved
# ---Data between 1203.101 and 1238.303 related to Standing is devided to 8 clips with length of 4 seconds each
# ---Residual of the data between 1203.101 and 1238.303 related to action Standing with duration 3.202 is saved
# ---Data between 1238.303 and 1373.839 related to Walking is devided to 33 clips with length of 4 seconds each
# ---Residual of the data between 1238.303 and 1373.839 related to action Walking with duration 3.536 is saved
# ---Data between 1373.839 and 1397.496 related to Standing is devided to 5 clips with length of 4 seconds each
# ---Residual of the data between 1373.839 and 1397.496 related to action Standing with duration 3.657 is saved
# ---Data between 1398.463 and 1406.071 related to Standing is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1398.463 and 1406.071 related to action Standing with duration 3.608 is saved
# ---Data between 1408.907 and 1409.708 related to action Standing with duration 0.801 is saved
# ---Data between 1412.544 and 1417.549 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1412.544 and 1417.549 related to action Walking with duration 1.005 is saved
# ---Data between 1430.562 and 1430.729 related to action Assisted Stand is removed due to the duration below 0.2 seconds
# ---Data between 1430.962 and 1432.831 related to action Stand-to-Sit with duration 1.869 is saved
# ---Data between 1432.831 and 1845.109 related to Sitting is devided to 103 clips with length of 4 seconds each
# ---Residual of the data between 1432.831 and 1845.109 related to action Sitting with duration 0.278 is saved
# ---Data between 1845.443 and 2574.071 related to Sitting is devided to 182 clips with length of 4 seconds each
# ---Residual of the data between 1845.443 and 2574.071 related to action Sitting with duration 0.628 is saved
# ---Data between 2574.071 and 2574.138 related to action PGT N/A is removed due to the duration below 0.2 seconds
# ---Data between 2574.138 and 2658.825 related to Sitting is devided to 21 clips with length of 4 seconds each
# ---Residual of the data between 2574.138 and 2658.825 related to action Sitting with duration 0.687 is saved
# ---Data between 2659.359 and 2671.236 related to Sitting is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 2659.359 and 2671.236 related to action Sitting with duration 3.877 is saved
# ---Data between 2671.568 and 2672.469 related to action Sitting with duration 0.901 is saved
# ---Data between 2672.736 and 2673.837 related to action Sitting with duration 1.101 is saved
# ---Data between 2693.924 and 2701.198 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 2693.924 and 2701.198 related to action Walking with duration 3.274 is saved
# ---Data between 2701.198 and 2702.9 related to action Standing with duration 1.702 is saved
# ---Data between 2702.9 and 2705.502 related to action Walking with duration 2.602 is saved
# ---Data between 2705.502 and 3187.951 related to Standing is devided to 120 clips with length of 4 seconds each
# ---Residual of the data between 2705.502 and 3187.951 related to action Standing with duration 2.449 is saved
# ---Data between 3187.951 and 3192.155 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3187.951 and 3192.155 related to action Walking with duration 0.204 is saved
# ---Data between 3192.155 and 3205.669 related to Standing is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 3192.155 and 3205.669 related to action Standing with duration 1.514 is saved
# ---Data between 3205.669 and 3208.438 related to action Walking with duration 2.769 is saved
# ---Data between 3208.438 and 3213.276 related to Standing is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3208.438 and 3213.276 related to action Standing with duration 0.838 is saved
# ---Data between 3213.276 and 3220.083 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3213.276 and 3220.083 related to action Walking with duration 2.807 is saved
# ---Data between 3220.383 and 3221.418 related to action Walking with duration 1.035 is saved
# ---Data between 3235.165 and 3245.976 related to Standing is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 3235.165 and 3245.976 related to action Standing with duration 2.811 is saved
# ---Data between 3262.525 and 3282.212 related to Standing is devided to 4 clips with length of 4 seconds each
# ---Residual of the data between 3262.525 and 3282.212 related to action Standing with duration 3.687 is saved
# ---Data between 3310.507 and 3324.621 related to Standing is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 3310.507 and 3324.621 related to action Standing with duration 2.114 is saved
# ---Data between 3351.748 and 3355.919 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Data between 3355.919 and 3358.655 related to action Standing with duration 2.736 is saved
# ---Data between 3358.655 and 3388.551 related to Walking is devided to 7 clips with length of 4 seconds each
# ---Residual of the data between 3358.655 and 3388.551 related to action Walking with duration 1.896 is saved
# ---Data between 3388.551 and 3392.789 related to Standing is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3388.551 and 3392.789 related to action Standing with duration 0.238 is saved
# ---Data between 3392.789 and 3398.862 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3392.789 and 3398.862 related to action Walking with duration 2.073 is saved
# ---Data between 3430.894 and 3435.198 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3430.894 and 3435.198 related to action Walking with duration 0.304 is saved
# ---Data between 3435.198 and 3442.038 related to Standing is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3435.198 and 3442.038 related to action Standing with duration 2.84 is saved
# ---Data between 3442.038 and 3468.898 related to Walking is devided to 6 clips with length of 4 seconds each
# ---Residual of the data between 3442.038 and 3468.898 related to action Walking with duration 2.86 is saved
# ---Data between 3468.898 and 3577.707 related to Standing is devided to 27 clips with length of 4 seconds each
# ---Residual of the data between 3468.898 and 3577.707 related to action Standing with duration 0.809 is saved
# ---Data between 3580.176 and 3584.047 related to action Walking with duration 3.871 is saved
# ---Data between 3584.047 and 3585.949 related to action Standing with duration 1.902 is saved
# ---Data between 3589.352 and 3596.259 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3589.352 and 3596.259 related to action Walking with duration 2.907 is saved
# ---Data between 3663.259 and 3803.966 related to Sitting is devided to 35 clips with length of 4 seconds each
# ---Residual of the data between 3663.259 and 3803.966 related to action Sitting with duration 0.707 is saved
# ---Data between 3803.966 and 3809.472 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3803.966 and 3809.472 related to action Sit-to-Stand with duration 1.506 is saved
# ---Data between 3810.873 and 3820.716 related to Walking is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 3810.873 and 3820.716 related to action Walking with duration 1.843 is saved
# ---processing subject 34 visit  1
# ---Data between 0.0 and 609.316 related to Sitting is devided to 152 clips with length of 4 seconds each
# ---Residual of the data between 0.0 and 609.316 related to action Sitting with duration 1.316 is saved
# ---Data between 610.051 and 617.826 related to Sitting is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 610.051 and 617.826 related to action Sitting with duration 3.775 is saved
# ---Data between 618.576 and 775.646 related to Sitting is devided to 39 clips with length of 4 seconds each
# ---Residual of the data between 618.576 and 775.646 related to action Sitting with duration 1.07 is saved
# ---Data between 776.086 and 813.636 related to Sitting is devided to 9 clips with length of 4 seconds each
# ---Residual of the data between 776.086 and 813.636 related to action Sitting with duration 1.55 is saved
# ---Data between 814.203 and 1188.123 related to Sitting is devided to 93 clips with length of 4 seconds each
# ---Residual of the data between 814.203 and 1188.123 related to action Sitting with duration 1.92 is saved
# ---Data between 1188.123 and 1195.762 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1188.123 and 1195.762 related to action Sit-to-Stand with duration 3.639 is saved
# ---Data between 1195.773 and 1196.509 related to action Standing with duration 0.736 is saved
# ---Data between 1196.509 and 1199.216 related to action Stand-to-Sit with duration 2.707 is saved
# ---Data between 1199.224 and 1205.094 related to Sitting is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1199.224 and 1205.094 related to action Sitting with duration 1.87 is saved
# ---Data between 1205.108 and 1212.041 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1205.108 and 1212.041 related to action Sit-to-Stand with duration 2.933 is saved
# ---Data between 1212.041 and 1213.345 related to action Standing with duration 1.304 is saved
# ---Data between 1213.345 and 1216.296 related to action Stand-to-Sit with duration 2.951 is saved
# ---Data between 1216.296 and 1231.675 related to Sitting is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 1216.296 and 1231.675 related to action Sitting with duration 3.379 is saved
# ---Data between 1231.675 and 1233.062 related to action Sit-to-Stand with duration 1.387 is saved
# ---Data between 1233.062 and 1234.806 related to action Sitting with duration 1.744 is saved
# ---Data between 1234.806 and 1236.643 related to action Sit-to-Stand with duration 1.837 is saved
# ---Data between 1236.643 and 1238.364 related to action Sitting with duration 1.721 is saved
# ---Data between 1238.368 and 1240.105 related to action Sit-to-Stand with duration 1.737 is saved
# ---Data between 1240.105 and 1240.539 related to action Sitting with duration 0.434 is saved
# ---Data between 1240.539 and 1242.941 related to action Sit-to-Stand with duration 2.402 is saved
# ---Data between 1242.941 and 1245.444 related to action Standing with duration 2.503 is saved
# ---Data between 1245.444 and 1247.499 related to action Stand-to-Sit with duration 2.055 is saved
# ---Data between 1247.499 and 1255.587 related to Sitting is devided to 2 clips with length of 4 seconds each
# ---Data between 1255.587 and 1257.867 related to action Sit-to-Stand with duration 2.28 is saved
# ---Data between 1257.867 and 1258.991 related to action Sitting with duration 1.124 is saved
# ---Data between 1258.998 and 1262.448 related to action Sit-to-Stand with duration 3.45 is saved
# ---Data between 1262.448 and 1264.529 related to action Standing with duration 2.081 is saved
# ---Data between 1264.529 and 1266.772 related to action Stand-to-Sit with duration 2.243 is saved
# ---Data between 1266.772 and 1313.405 related to Sitting is devided to 11 clips with length of 4 seconds each
# ---Residual of the data between 1266.772 and 1313.405 related to action Sitting with duration 2.633 is saved
# ---Data between 1313.405 and 1314.835 related to action Sit-to-Stand with duration 1.43 is saved
# ---Data between 1314.835 and 1315.431 related to action Sitting with duration 0.596 is saved
# ---Data between 1315.431 and 1317.938 related to action Sit-to-Stand with duration 2.507 is saved
# ---Data between 1317.938 and 1318.488 related to action Standing with duration 0.55 is saved
# ---Data between 1318.488 and 1321.286 related to action Stand-to-Sit with duration 2.798 is saved
# ---Data between 1321.286 and 1323.069 related to action Sitting with duration 1.783 is saved
# ---Data between 1323.069 and 1328.19 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1323.069 and 1328.19 related to action Sit-to-Stand with duration 1.121 is saved
# ---Data between 1328.199 and 1329.034 related to action Standing with duration 0.835 is saved
# ---Data between 1329.034 and 1331.573 related to action Stand-to-Sit with duration 2.539 is saved
# ---Data between 1331.573 and 1334.676 related to action Sitting with duration 3.103 is saved
# ---Data between 1334.676 and 1335.406 related to action Sit-to-Stand with duration 0.73 is saved
# ---Data between 1335.406 and 1335.941 related to action Sitting with duration 0.535 is saved
# ---Data between 1335.942 and 1336.489 related to action Sit-to-Stand with duration 0.547 is saved
# ---Data between 1336.489 and 1337.102 related to action Sitting with duration 0.613 is saved
# ---Data between 1337.102 and 1338.603 related to action Sit-to-Stand with duration 1.501 is saved
# ---Data between 1338.603 and 1339.104 related to action Sitting with duration 0.501 is saved
# ---Data between 1339.104 and 1341.506 related to action Sit-to-Stand with duration 2.402 is saved
# ---Data between 1341.506 and 1342.849 related to action Standing with duration 1.343 is saved
# ---Data between 1342.849 and 1345.488 related to action Stand-to-Sit with duration 2.639 is saved
# ---Data between 1345.488 and 1349.311 related to action Sitting with duration 3.823 is saved
# ---Data between 1349.311 and 1350.616 related to action Sit-to-Stand with duration 1.305 is saved
# ---Data between 1350.616 and 1351.318 related to action Sitting with duration 0.702 is saved
# ---Data between 1351.318 and 1352.323 related to action Sit-to-Stand with duration 1.005 is saved
# ---Data between 1352.323 and 1353.292 related to action Sitting with duration 0.969 is saved
# ---Data between 1353.292 and 1356.762 related to action Sit-to-Stand with duration 3.47 is saved
# ---Data between 1356.762 and 1357.726 related to action Standing with duration 0.964 is saved
# ---Data between 1357.726 and 1360.158 related to action Stand-to-Sit with duration 2.432 is saved
# ---Data between 1360.158 and 1365.214 related to Sitting is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1360.158 and 1365.214 related to action Sitting with duration 1.056 is saved
# ---Data between 1365.214 and 1366.734 related to action Sit-to-Stand with duration 1.52 is saved
# ---Data between 1366.734 and 1367.703 related to action Sitting with duration 0.969 is saved
# ---Data between 1367.703 and 1371.462 related to action Sit-to-Stand with duration 3.759 is saved
# ---Data between 1371.462 and 1372.704 related to action Standing with duration 1.242 is saved
# ---Data between 1372.704 and 1375.407 related to action Stand-to-Sit with duration 2.703 is saved
# ---Data between 1375.407 and 1388.42 related to Sitting is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 1375.407 and 1388.42 related to action Sitting with duration 1.013 is saved
# ---Data between 1388.42 and 1389.988 related to action Sit-to-Stand with duration 1.568 is saved
# ---Data between 1389.988 and 1390.622 related to action Sitting with duration 0.634 is saved
# ---Data between 1390.622 and 1395.46 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1390.622 and 1395.46 related to action Sit-to-Stand with duration 0.838 is saved
# ---Data between 1395.46 and 1549.06 related to Standing is devided to 38 clips with length of 4 seconds each
# ---Residual of the data between 1395.46 and 1549.06 related to action Standing with duration 1.6 is saved
# ---Data between 1549.327 and 1550.095 related to action Standing with duration 0.768 is saved
# ---Data between 1550.095 and 1555.954 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1550.095 and 1555.954 related to action Walking with duration 1.859 is saved
# ---Data between 1555.954 and 1578.4 related to Standing is devided to 5 clips with length of 4 seconds each
# ---Residual of the data between 1555.954 and 1578.4 related to action Standing with duration 2.446 is saved
# ---Data between 1578.4 and 1579.803 related to action Walking with duration 1.403 is saved
# ---Data between 1592.71 and 1597.562 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1592.71 and 1597.562 related to action Walking with duration 0.852 is saved
# ---Data between 1597.562 and 1616.448 related to Standing is devided to 4 clips with length of 4 seconds each
# ---Residual of the data between 1597.562 and 1616.448 related to action Standing with duration 2.886 is saved
# ---Data between 1616.448 and 1655.432 related to Walking is devided to 9 clips with length of 4 seconds each
# ---Residual of the data between 1616.448 and 1655.432 related to action Walking with duration 2.984 is saved
# ---Data between 1655.432 and 1718.159 related to Standing is devided to 15 clips with length of 4 seconds each
# ---Residual of the data between 1655.432 and 1718.159 related to action Standing with duration 2.727 is saved
# ---Data between 1718.159 and 1851.685 related to Walking is devided to 33 clips with length of 4 seconds each
# ---Residual of the data between 1718.159 and 1851.685 related to action Walking with duration 1.526 is saved
# ---Data between 1851.685 and 1880.608 related to Standing is devided to 7 clips with length of 4 seconds each
# ---Residual of the data between 1851.685 and 1880.608 related to action Standing with duration 0.923 is saved
# ---Data between 1880.608 and 1885.783 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 1880.608 and 1885.783 related to action Walking with duration 1.175 is saved
# ---Data between 1900.031 and 1902.0 related to action Stand-to-Sit with duration 1.969 is saved
# ---Data between 1902.0 and 2745.946 related to Sitting is devided to 210 clips with length of 4 seconds each
# ---Residual of the data between 1902.0 and 2745.946 related to action Sitting with duration 3.946 is saved
# ---Data between 2745.946 and 2746.08 related to action PGT N/A is removed due to the duration below 0.2 seconds
# ---Data between 2746.08 and 2746.949 related to action Sitting with duration 0.869 is saved
# ---Data between 2762.76 and 2763.282 related to action Sitting with duration 0.522 is saved
# ---Data between 2763.794 and 2764.751 related to action Sitting with duration 0.957 is saved
# ---Data between 2764.751 and 2768.332 related to action Sit-to-Stand with duration 3.581 is saved
# ---Data between 2768.332 and 2773.003 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 2768.332 and 2773.003 related to action Walking with duration 0.671 is saved
# ---Data between 2773.003 and 2773.245 related to action Standing with duration 0.242 is saved
# ---Data between 2773.646 and 2778.834 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 2773.646 and 2778.834 related to action Walking with duration 1.188 is saved
# ---Data between 2779.134 and 2780.945 related to action Standing with duration 1.811 is saved
# ---Data between 2781.146 and 2783.213 related to action Standing with duration 2.067 is saved
# ---Data between 2783.481 and 2786.183 related to action Standing with duration 2.702 is saved
# ---Data between 2786.45 and 2966.43 related to Standing is devided to 44 clips with length of 4 seconds each
# ---Residual of the data between 2786.45 and 2966.43 related to action Standing with duration 3.98 is saved
# ---Data between 2966.873 and 2975.768 related to Standing is devided to 2 clips with length of 4 seconds each
# ---Residual of the data between 2966.873 and 2975.768 related to action Standing with duration 0.895 is saved
# ---Data between 2976.168 and 2980.768 related to Standing is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 2976.168 and 2980.768 related to action Standing with duration 0.6 is saved
# ---Data between 2980.768 and 2988.48 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 2980.768 and 2988.48 related to action Walking with duration 3.712 is saved
# ---Data between 2988.48 and 2989.22 related to action Standing with duration 0.74 is saved
# ---Data between 2989.22 and 2991.989 related to action Walking with duration 2.769 is saved
# ---Data between 2991.989 and 2995.392 related to action Standing with duration 3.403 is saved
# ---Data between 2995.392 and 2998.562 related to action Walking with duration 3.17 is saved
# ---Data between 2998.562 and 3002.099 related to action Standing with duration 3.537 is saved
# ---Data between 3002.332 and 3003.233 related to action Standing with duration 0.901 is saved
# ---Data between 3003.233 and 3006.198 related to action Walking with duration 2.965 is saved
# ---Data between 3019.568 and 3045.642 related to Standing is devided to 6 clips with length of 4 seconds each
# ---Residual of the data between 3019.568 and 3045.642 related to action Standing with duration 2.074 is saved
# ---Data between 3045.642 and 3051.715 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3045.642 and 3051.715 related to action Walking with duration 2.073 is saved
# ---Data between 3051.715 and 3068.969 related to Standing is devided to 4 clips with length of 4 seconds each
# ---Residual of the data between 3051.715 and 3068.969 related to action Standing with duration 1.254 is saved
# ---Data between 3068.969 and 3113.31 related to Walking is devided to 11 clips with length of 4 seconds each
# ---Residual of the data between 3068.969 and 3113.31 related to action Walking with duration 0.341 is saved
# ---Data between 3113.31 and 3146.378 related to Standing is devided to 8 clips with length of 4 seconds each
# ---Residual of the data between 3113.31 and 3146.378 related to action Standing with duration 1.068 is saved
# ---Data between 3146.378 and 3184.351 related to Walking is devided to 9 clips with length of 4 seconds each
# ---Residual of the data between 3146.378 and 3184.351 related to action Walking with duration 1.973 is saved
# ---Data between 3184.351 and 3285.16 related to Standing is devided to 25 clips with length of 4 seconds each
# ---Residual of the data between 3184.351 and 3285.16 related to action Standing with duration 0.809 is saved
# ---Data between 3285.16 and 3299.214 related to Walking is devided to 3 clips with length of 4 seconds each
# ---Residual of the data between 3285.16 and 3299.214 related to action Walking with duration 2.054 is saved
# ---Data between 3309.941 and 3317.913 related to Walking is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3309.941 and 3317.913 related to action Walking with duration 3.972 is saved
# ---Data between 3334.468 and 3381.654 related to Sitting is devided to 11 clips with length of 4 seconds each
# ---Residual of the data between 3334.468 and 3381.654 related to action Sitting with duration 3.186 is saved
# ---Data between 3381.999 and 3409.945 related to Sitting is devided to 6 clips with length of 4 seconds each
# ---Residual of the data between 3381.999 and 3409.945 related to action Sitting with duration 3.946 is saved
# ---Data between 3410.163 and 3410.173 related to action Sitting is removed due to the duration below 0.2 seconds
# ---Data between 3410.173 and 3415.524 related to Sit-to-Stand is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3410.173 and 3415.524 related to action Sit-to-Stand with duration 1.351 is saved
# ---Data between 3415.524 and 3432.429 related to Standing is devided to 4 clips with length of 4 seconds each
# ---Residual of the data between 3415.524 and 3432.429 related to action Standing with duration 0.905 is saved
# ---Data between 3432.429 and 3435.356 related to action Stand-to-Sit with duration 2.927 is saved
# ---Data between 3435.356 and 3440.047 related to Sitting is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3435.356 and 3440.047 related to action Sitting with duration 0.691 is saved
# ---Data between 3440.975 and 3445.75 related to Sitting is devided to 1 clips with length of 4 seconds each
# ---Residual of the data between 3440.975 and 3445.75 related to action Sitting with duration 0.775 is saved
# ---Data between 3447.483 and 3604.706 related to Sitting is devided to 39 clips with length of 4 seconds each
# ---Residual of the data between 3447.483 and 3604.706 related to action Sitting with duration 1.223 is saved
# ---Data between 3604.706 and 3607.342 related to action Sit-to-Stand with duration 2.636 is saved
# ---Data between 3607.342 and 3627.402 related to Standing is devided to 5 clips with length of 4 seconds each
